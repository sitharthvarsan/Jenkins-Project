# %%
# !pip install pandas
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("BoB.xlsx")

# %%
selected_cols = [
    'account_number',
    'company_sizing',
    'agreement_number',
    'agreement_start_date',
    'agreement_end_date',
    'total_bob',
    'unit_amount',
    'line_of_business',
    'msdyn_product_number',
    'service_interval'
]

df = df[selected_cols]

# %%
df.head()
# Out:
#       account_number company_sizing                    agreement_number  \
# 0  UK02-CGBA029544-L          >1000  GBC4019041-Machine Services-327311
# 1  UK02-CGBA029544-L          >1000  GBC4021962-Machine Services-332280
# 2  UK02-CGBA029544-L          >1000  GBC4021962-Machine Services-332282
# 3  UK02-CGBA124601-L          20-49               GBC4000950-Auto waste
# 4  UK02-CGBA034502-L          50-99                GBC3028394-Chemistry
#
#   agreement_start_date agreement_end_date  total_bob  unit_amount  \
# 0           2025-03-17         2026-03-16  117745.68      9812.14
# 1           2025-04-14         2028-04-13  105967.68      8830.64
# 2           2025-04-14         2028-04-13  105967.68      8830.64
# 3           2022-06-24         2026-06-23   92242.56      7686.88
# 4           2024-11-04         2025-11-03   83206.92      6933.91
#
#    line_of_business  msdyn_product_number  service_interval
# 0  Machine Services  ISK400EAA-001483-001               1.0
# ...
